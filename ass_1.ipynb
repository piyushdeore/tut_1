# %% [markdown]
# # Name-Piyush Deore
# Roll -33218
# Batch-L10
# Class-Te10

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Heart.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
df.tail()
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No

# %%
#Find shape of data
df.shape
# Out:
# (303, 15)

# %%
#find missing values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
print("Total Missing Values :", df.isnull().sum().sum())
# Out:
# Total Missing Values : 6

# %%
#Find dattypes of each  column

df.dtypes
# Out:
# Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
#Finding number of zeroes

(df==0).sum()
# Out:
# Unnamed: 0      0
# Age             0
# Sex            97
# ChestPain       0
# RestBP          0
# Chol            0
# Fbs           258
# RestECG       151
# MaxHR           0
# ExAng         204
# Oldpeak        99
# Slope           0
# Ca            176
# Thal            0
# AHD             0
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
#Finding mean age of pateints
df["Age"].mean()
# Out:
# 54.43894389438944

# %%
# Extract only Age, Sex, Chestpain, RestBP, Chol
var=df[['Age','Sex','RestBP','Chol','ChestPain']]

# %%
var
# Out:
#      Age  Sex  RestBP  Chol     ChestPain
# 0     63    1     145   233       typical
# 1     67    1     160   286  asymptomatic
# 2     67    1     120   229  asymptomatic
# 3     37    1     130   250    nonanginal
# 4     41    0     130   204    nontypical
# ..   ...  ...     ...   ...           ...
# 298   45    1     110   264       typical
# 299   68    1     144   193  asymptomatic
# 300   57    1     130   131  asymptomatic
# 301   57    0     130   236    nontypical
# 302   38    1     138   175    nonanginal
#
# [303 rows x 5 columns]

# %%
#Randomly divide dataset in training (75%) and testing (25%)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(var,df,test_size=0.25)

# %%
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(var,df,test_size=0.25)

# %%
xTest
# Out:
#      Age  Sex  RestBP  Chol     ChestPain
# 115   41    1     135   203    nontypical
# 229   66    1     112   212  asymptomatic
# 259   57    1     124   261    nontypical
# 64    54    1     120   188  asymptomatic
# 20    64    1     110   211       typical
# ..   ...  ...     ...   ...           ...
# 221   54    0     108   267    nonanginal
# 170   70    1     160   269    nonanginal
# 232   49    1     118   149    nonanginal
# 223   53    1     123   282  asymptomatic
# 230   52    0     136   196    nonanginal
#
# [76 rows x 5 columns]

# %%
xTrain
# Out:
#      Age  Sex  RestBP  Chol     ChestPain
# 131   51    1      94   227    nonanginal
# 7     57    0     120   354  asymptomatic
# 89    51    0     130   256    nonanginal
# 294   63    0     124   197  asymptomatic
# 61    46    0     142   177    nonanginal
# ..   ...  ...     ...   ...           ...
# 105   54    1     108   309    nontypical
# 117   35    0     138   183  asymptomatic
# 70    65    0     155   269    nonanginal
# 301   57    0     130   236    nontypical
# 264   61    1     138   166  asymptomatic
#
# [227 rows x 5 columns]

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (14, 9))
plt.hist(df["ChestPain"], color = "green");
plt.title("Frequency of Chest Pain", fontsize = 15);
plt.xlabel("Types of Chest Pain", fontsize = 15)
plt.ylabel("Number of people", fontsize = 15)

# %%
count = np.array(df.AHD.value_counts())
count
# Out:
# array([164, 139], dtype=int64)

# %%
plt.figure(figsize = (14, 9))
plt.title("Heart Disease", fontsize = 15)
plt.pie(count,labels = ["Yes", "No"], explode = None, labeldistance = 0.5, textprops = {'fontsize' : 25});

# %%
plt.hist(df["Age"],bins=15,rwidth=1,label="Age Count")
plt.title("Age Histogram")
plt.xlabel("Age range")
plt.ylabel("Count according to Age")
plt.legend(loc="upper left");

# %%
TP=45
FP=55
FN=5
TN=395


ACC=(TP+TN)/500
PRE=(TP)/(TP+FP)
REC=(TP)/(TP+FN)

print("Accuracy: ",ACC)
print("Precision: ",PRE)
print("Recall: ",REC)
# Out:
# Accuracy:  0.88
# Precision:  0.45
# Recall:  0.9

# %%
F1=(2*PRE*REC)/(PRE+REC)
print("F1 score= ",F1)
# Out:
# F1 score=  0.6
